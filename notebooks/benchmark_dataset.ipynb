# %%
import anndata as ad
import pandas as pd
import numpy as np

adata_bm = ad.read("/aloy/home/ddalton/projects/scGPT_playground/data/test_1/test_2.h5ad")
adata_nw = ad.read("/aloy/home/ddalton/projects/scGPT_playground/data/pp_data-24-09-14-01/data.h5ad")
# Out:
# /home/ddalton/miniconda3/envs/scgpt/lib/python3.10/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(

# %%
adata.obs
# Out:
#                               ids             celltype  celltype_id  \
# 0      DSA00042;GSM185813;Control              Control            4
# 1      DSA00042;GSM185815;Control              Control            4
# 2      DSA00042;GSM185817;Control              Control            4
# 3      DSA00042;GSM185819;Control              Control            4
# 4      DSA00042;GSM185821;Control              Control            4
# ...                           ...                  ...          ...
# 10578     DSA10289;GSM783003;Case  Lung Adenocarcinoma            5
# 10579     DSA10289;GSM783004;Case  Lung Adenocarcinoma            5
# 10580     DSA10289;GSM783005;Case  Lung Adenocarcinoma            5
# 10581     DSA10289;GSM783006;Case  Lung Adenocarcinoma            5
# 10582     DSA10289;GSM783007;Case  Lung Adenocarcinoma            5
#
#       dataset_id  batch_id  train_test str_batch
# 0        GSE7670        93         0.0         0
# 1        GSE7670        93         0.0         0
# ...
