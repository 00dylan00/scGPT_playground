# %% [markdown]
# # Check Zero Shot

# %%
import numpy as np
import pickle
import sys
sys.path.append("../..")
from src.utils import viz as vz
# load numpy 
valid_1 = pickle.load(open("/aloy/home/ddalton/projects/scGPT_playground/outputs/run-25-09-19-02/all_outputs_test.pkl", "rb"))
valid_2 = np.load("/aloy/scratch/ddalton/projects/scGPT_playground/outputs/run-25-09-19-02/test-ft_embeddings.npy")
valid_3 = np.load("/aloy/scratch/ddalton/projects/scGPT_playground/outputs/run-25-09-19-02/test-pt_embeddings.npy")

valid_1 = vz.merge_embeddings(valid_1[0])

# %%
all_zs = np.load("/aloy/scratch/ddalton/projects/scGPT_playground/outputs/run-25-09-19-02/zero_shot-ft_embeddings.npy")

# %%
from scipy.spatial import distance

dist_1 = distance.cdist(valid_1, valid_2, 'cosine')

# %%
dist_1
# Out:
# array([[0.        , 0.12797706, 0.05268088, ..., 0.72628675, 0.80135863,
#         0.7831261 ],
#        [0.12797706, 0.        , 0.04984492, ..., 0.74921971, 0.78145535,
#         0.76840576],
#        [0.05268088, 0.04984492, 0.        , ..., 0.74389193, 0.78655185,
#         0.77550053],
#        ...,
#        [0.72628675, 0.74921971, 0.74389193, ..., 0.        , 0.12891815,
#         0.11676534],
#        [0.80135863, 0.78145535, 0.78655185, ..., 0.12891815, 0.        ,
#         0.01178588],
#        [0.7831261 , 0.76840576, 0.77550053, ..., 0.11676534, 0.01178588,
#         0.        ]])
