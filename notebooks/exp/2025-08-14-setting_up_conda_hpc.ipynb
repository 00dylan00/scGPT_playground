# %%
! pip install scgpt "flash-attn<1.0.5"
# Out:
# ...
#   Using cached scgpt-0.2.4-py3-none-any.whl.metadata (10.0 kB)
# ...
#   Using cached flash_attn-1.0.4.tar.gz (2.0 MB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [13 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 35, in <module>
#         File "/tmp/pip-install-93koe5x6/flash-attn_0a866f16cb6b40b2b72f0526a7a2c82e/setup.py", line 106, in <module>
#           raise_if_cuda_home_none("flash_attn")
#         File "/tmp/pip-install-93koe5x6/flash-attn_0a866f16cb6b40b2b72f0526a7a2c82e/setup.py", line 53, in raise_if_cuda_home_none
#           raise RuntimeError(
# ...

# %%
pip install --index-url https://download.pytorch.org/whl/cu117 torch==2.0.1 torchvision==0.15.2
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu117
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wheel ninja
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip wheel "flash-attn==1.0.4" -w /tmp/wheels --no-build-isolation
# Out:
# ...
#   Using cached flash_attn-1.0.4.tar.gz (2.0 MB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [13 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 35, in <module>
#         File "/tmp/pip-wheel-ubjarult/flash-attn_12554e726e0b46448a7b3f1d30d77169/setup.py", line 106, in <module>
#           raise_if_cuda_home_none("flash_attn")
#         File "/tmp/pip-wheel-ubjarult/flash-attn_12554e726e0b46448a7b3f1d30d77169/setup.py", line 53, in raise_if_cuda_home_none
#           raise RuntimeError(
#       RuntimeError: flash_attn was requested, but nvcc was not found.  Are you sure your environment has nvcc available?  If you're installing within a container from https://hub.docker.com/r/pytorch/pytorch, only images whose names contain 'devel' will provide nvcc.
#
#
# ...
