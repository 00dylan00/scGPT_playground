# %%
! pip install scgpt "flash-attn<1.0.5"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 5.1 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [13 lines of output]
#
#
#       torch.__version__  = 2.0.1+cu117
#
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 35, in <module>
#         File "/tmp/pip-install-b7pq3z0h/flash-attn_e1eac98c5dbc46eaaab99658b3f3e542/setup.py", line 106, in <module>
#           raise_if_cuda_home_none("flash_attn")
#         File "/tmp/pip-install-b7pq3z0h/flash-attn_e1eac98c5dbc46eaaab99658b3f3e542/setup.py", line 53, in raise_if_cuda_home_none
#           raise RuntimeError(
# ...
